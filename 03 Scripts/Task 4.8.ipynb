# %% [markdown]
# # Grouping Data & Aggregating Variables
# ## Contents:

# %%
#import libraries

import pandas as pd
import numpy as np
import os

# %%
#import data frame

orders_prods_merge = pd.read_pickle (r"C:\Users\thoms\Desktop\Data Analytics\Achievement 4\Instacart Basket Analysis\02 Data\Prepared Data\orders_products_merged.pkl")

# %%
path = r'C:\Users\thoms\Desktop\Data Analytics\Achievement 4\Instacart Basket Analysis'

# %%
#checking dataframe

orders_prods_merge.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2539329        1    prior             1          2                  8
# 2   2539329        1    prior             1          2                  8
# 3   2539329        1    prior             1          2                  8
# 4   2539329        1    prior             1          2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN       196.0                1.0        0.0
# 1                     NaN     14084.0                2.0        0.0
# 2                     NaN     12427.0                3.0        0.0
# 3                     NaN     26088.0                4.0        0.0
# 4                     NaN     26405.0                5.0        0.0
#
#                               product_name  aisle_id  department_id  prices  \
# ...

# %%
#checking dataframe

orders_prods_merge.shape
# Out:
# (32404859, 19)

# %% [markdown]
# # Question 2: In this Exercise, you learned how to find the aggregated mean of the “order_number” column grouped by “department_id” for a subset of your dataframe. Now, repeat this process for the entire dataframe.

# %%
#grouping department id with order number

orders_prods_merge.groupby('department_id')

# %%
orders_prods_merge.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1.0              15.457838
# 2.0              17.277920
# 3.0              17.170395
# 4.0              17.811403
# 5.0              15.215751
# 6.0              16.439806
# 7.0              17.225802
# 8.0              15.340650
# 9.0              15.895474
# 10.0             20.197148
# 11.0             16.170638
# 12.0             15.887671
# 13.0             16.583536
# 14.0             16.773669
# 15.0             16.165037
# 16.0             17.665606
# 17.0             15.694469
# 18.0             19.310397
# 19.0             17.177343
# 20.0             16.473447
# 21.0             22.902379

# %%
#Checking mean,min and max of the dataframe of department id

orders_prods_merge.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 1.0              15.457838   1  99
# 2.0              17.277920   1  99
# 3.0              17.170395   1  99
# 4.0              17.811403   1  99
# 5.0              15.215751   1  99
# 6.0              16.439806   1  99
# 7.0              17.225802   1  99
# 8.0              15.340650   1  99
# 9.0              15.895474   1  99
# 10.0             20.197148   1  99
# 11.0             16.170638   1  99
# 12.0             15.887671   1  99
# 13.0             16.583536   1  99
# 14.0             16.773669   1  99
# 15.0             16.165037   1  99
# 16.0             17.665606   1  99
# 17.0             15.694469   1  99
# 18.0             19.310397   1  99
# 19.0             17.177343   1  99
# 20.0             16.473447   1  99
# 21.0             22.902379   1  99

# %%
# Transform dataframe for max order

orders_prods_merge['max_order'] = orders_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
#checking data

orders_prods_merge.head(20)
# Out:
#     order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0    2539329        1    prior             1          2                  8
# 1    2539329        1    prior             1          2                  8
# 2    2539329        1    prior             1          2                  8
# 3    2539329        1    prior             1          2                  8
# 4    2539329        1    prior             1          2                  8
# 5    2398795        1    prior             2          3                  7
# 6    2398795        1    prior             2          3                  7
# 7    2398795        1    prior             2          3                  7
# 8    2398795        1    prior             2          3                  7
# 9    2398795        1    prior             2          3                  7
# 10   2398795        1    prior             2          3                  7
# ...

# %%
#sorting data in accending user_id values

orders_prods_merge.sort_values("user_id")
# Out:
#           order_id  user_id eval_set  order_number  order_dow  \
# 0          2539329        1    prior             1          2
# 32         3367565        1    prior             6          2
# 33          550135        1    prior             7          1
# 34          550135        1    prior             7          1
# 35          550135        1    prior             7          1
# ...            ...      ...      ...           ...        ...
# 32641173   1542354   206209    prior             3          5
# 32641172   1542354   206209    prior             3          5
# 32641171   1542354   206209    prior             3          5
# 32641169   1542354   206209    prior             3          5
# 32641266   2977660   206209    prior            13          1
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                     NaN       196.0
# 32                        7                    19.0     25133.0
# ...

# %%
# allowing no restrictions to data disply

pd.options.display.max_rows = None

# %%
#displaying 100 rows of data

orders_prods_merge.head(100)
# Out:
#      order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0     2539329        1    prior             1          2                  8
# 1     2539329        1    prior             1          2                  8
# 2     2539329        1    prior             1          2                  8
# 3     2539329        1    prior             1          2                  8
# 4     2539329        1    prior             1          2                  8
# 5     2398795        1    prior             2          3                  7
# 6     2398795        1    prior             2          3                  7
# 7     2398795        1    prior             2          3                  7
# 8     2398795        1    prior             2          3                  7
# 9     2398795        1    prior             2          3                  7
# 10    2398795        1    prior             2          3                  7
# ...

# %% [markdown]
# # Question 3: Analyze the result. How do the results for the entire dataframe differ from those of the subset? Include your comments in a markdown cell below the executed code.

# %% [markdown]
# ### Answer:  Analysis has been done above. When comparing with a subset which was doen in the exercise the mean value is really close, with the smaller subset having a slightly higher mean of 15,562 and the entire data frame had a 15,457 value.

# %% [markdown]
# # Question 4: Follow the instructions in the Exercise for creating a loyalty flag for existing customers using the transform() and loc() functions.

# %%
#Creating loyalty flags for customers

orders_prods_merge.loc[orders_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'
orders_prods_merge.loc[(orders_prods_merge['max_order'] <= 40) & (orders_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'
orders_prods_merge.loc[orders_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
# showing loyalty counts

orders_prods_merge['loyalty_flag'].value_counts (dropna = False)
# Out:
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: loyalty_flag, dtype: int64

# %%
orde_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      New customer             1
# 1         1      New customer             1
# 2         1      New customer             1
# 3         1      New customer             1
# 4         1      New customer             1
# 5         1      New customer             2
# 6         1      New customer             2
# 7         1      New customer             2
# 8         1      New customer             2
# 9         1      New customer             2
# 10        1      New customer             2
# 11        1      New customer             3
# 12        1      New customer             3
# 13        1      New customer             3
# 14        1      New customer             3
# 15        1      New customer             3
# 16        1      New customer             4
# 17        1      New customer             4
# 18        1      New customer             4
# 19        1      New customer             4
# ...

# %% [markdown]
# # Question 5: The marketing team at Instacart wants to know whether there’s a difference between the spending habits of the three types of customers you identified. Use the loyalty flag you created and check the basic statistics of the product prices for each loyalty category (Loyal Customer, Regular Customer, and New Customer). What you’re trying to determine is whether the prices of products purchased by loyal customers differ from those purchased by regular or new customers.

# %%
#Grouping the loyalty status via price spent 

orders_prods_merge.groupby('loyalty_flag').agg({'prices': ['mean', 'min', 'max']})
# Out:
#                      prices
#                        mean  min      max
# loyalty_flag
# Loyal customer    10.386336  1.0  99999.0
# New customer      13.294670  1.0  99999.0
# Regular customer  12.495717  1.0  99999.0

# %% [markdown]
# ### Answer:  The question asked by the marketing team - new customers are spending the most on average, whereas loyal customers are spending less on products. Regular customers are spending more towards the same as new customers.

# %% [markdown]
# # Question 6: The team now wants to target different types of spenders in their marketing campaigns. This can be achieved by looking at the prices of the items people are buying. Create a spending flag for each user based on the average price across all their orders using the following criteria:
# ## If the mean of the prices of products purchased by a user is lower than 10, then flag them as a “Low spender.”
# ## If the mean of the prices of products purchased by a user is higher than or equal to 10, then flag them as a “High spender.”

# %%
#Grouping user_id with price spent 

orders_prods_merge.groupby('user_id').agg({'prices': ['mean', 'min', 'max']}).head()
# Out:
#            prices
#              mean  min   max
# user_id
# 1        6.367797  1.0  14.0
# 2        7.515897  1.3  14.8
# 3        8.197727  1.3  14.4
# 4        8.205556  1.4  14.6
# 5        9.189189  3.2  14.8

# %%
# Using transform for a new column

orders_prods_merge['spending'] = orders_prods_merge.groupby(['user_id'])['prices'].transform(np.max)

# %%
# Create a low / higher spending flag

orders_prods_merge.loc[orders_prods_merge['spending'] > 10, 'spending_flag'] = 'Low spender'
orders_prods_merge.loc[orders_prods_merge['spending'] <= 10, 'spending_flag'] = 'Higher Spender'

# %%
orders_prods_merge[['user_id', 'spending_flag', 'spending']].head(20)
# Out:
#     user_id spending_flag  spending
# 0         1   Low spender      14.0
# 1         1   Low spender      14.0
# 2         1   Low spender      14.0
# 3         1   Low spender      14.0
# 4         1   Low spender      14.0
# 5         1   Low spender      14.0
# 6         1   Low spender      14.0
# 7         1   Low spender      14.0
# 8         1   Low spender      14.0
# 9         1   Low spender      14.0
# 10        1   Low spender      14.0
# 11        1   Low spender      14.0
# 12        1   Low spender      14.0
# 13        1   Low spender      14.0
# 14        1   Low spender      14.0
# 15        1   Low spender      14.0
# 16        1   Low spender      14.0
# 17        1   Low spender      14.0
# 18        1   Low spender      14.0
# 19        1   Low spender      14.0

# %% [markdown]
# # Question 7: In order to send relevant notifications to users within the app (for instance, asking users if they want to buy the same item again), the Instacart team wants you to determine frequent versus non-frequent customers. Create an order frequency flag that marks the regularity of a user’s ordering behavior according to the median in the “days_since_prior_order” column. The criteria for the flag should be as follows:
# ## If the median of “days_since_prior_order” is higher than 20, then the customer should be labeled a “Non-frequent customer.”
# ## If the median is higher than 10 and lower than or equal to 20, then the customer should be labeled a “Regular customer.”
# ## If the median is lower than or equal to 10, then the customer should be labeled a “Frequent customer.”

# %%
orders_prods_merge['frequency'] = orders_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.max)

# %%
orders_prods_merge.loc[orders_prods_merge['frequency'] > 20, 'frequency_flag'] = 'Non frequent customer'
orders_prods_merge.loc[(orders_prods_merge['frequency'] <= 20) & (orders_prods_merge['frequency'] > 10), 'frequency_flag'] = 'Regular customer'
orders_prods_merge.loc[orders_prods_merge['frequency'] <= 10, 'frequency_flag'] = 'frequent customer'

# %%
orders_prods_merge[['user_id', 'frequency_flag', 'frequency']].head(20)
# Out:
#     user_id         frequency_flag  frequency
# 0         1  Non frequent customer       30.0
# 1         1  Non frequent customer       30.0
# 2         1  Non frequent customer       30.0
# 3         1  Non frequent customer       30.0
# 4         1  Non frequent customer       30.0
# 5         1  Non frequent customer       30.0
# 6         1  Non frequent customer       30.0
# 7         1  Non frequent customer       30.0
# 8         1  Non frequent customer       30.0
# 9         1  Non frequent customer       30.0
# 10        1  Non frequent customer       30.0
# 11        1  Non frequent customer       30.0
# 12        1  Non frequent customer       30.0
# 13        1  Non frequent customer       30.0
# 14        1  Non frequent customer       30.0
# 15        1  Non frequent customer       30.0
# 16        1  Non frequent customer       30.0
# 17        1  Non frequent customer       30.0
# 18        1  Non frequent customer       30.0
# ...

# %%
orders_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged.pkl'))
